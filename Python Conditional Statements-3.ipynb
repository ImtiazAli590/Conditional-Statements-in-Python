# %% [markdown]
# # $\color{blue}{\text{Conditional Statements}}$

# %% [markdown]
# #### $\text{Conditional Statements basically means "To perform a task if a certain condition is fulfilled}$
# Flow chart demonstration of conditional statement

# %% [markdown]
# ### ![if_statement_flowchart.webp](attachment:if_statement_flowchart.webp)

# %% [markdown]
# **There are three types of conditional statements**
#
# ****1) if Statement****
#
# ****2) if-else Statement****
#
# ****3) if-elif-else Statement****

# %% [markdown]
# ## $\color{blue}{\text{1. if statements}}$

# %% [markdown]
# ![ifstatement.png](attachment:ifstatement.png)

# %% [markdown]
# ### $Syntax$

# %%
# if condition:
#     perform task

# %% [markdown]
# ****"input()" is a Python's built-in function that takes input from user****

# %%
x = input("Enter 1st Value: ")
x = int(x)
y = input("Enter 2nd Value: ")
y = int(y)
# conditional block portion
if x == y:  
    print('x is equal to y')
# Out:
# Enter 1st Value: 1
# Enter 2nd Value: 2

# %% [markdown]
# **In the above example,**  " x == y " is the condition
#
# *The body of " if " is executed only if the above condition is met*
#
# *When the variable x is equal to variable y, the given condition is true and statements inside the body of " if " are executed*
#
# *If x is not equal to y , the given condition is false and instructions inside the body of " if " are ignored*
#
# *The print() function lies outside of the if statement therefore, it is executed regardless of the condition*

# %% [markdown]
# ****The statement only runs when the given condition is met otherwise it will not run****

# %%
x = 30
y = 50
if x < y:
    print('x is less than y')
# Out:
# x is less than y

# %%
a = 10 
if a > 0:
    print(a, 'is a positive number')
# Out:
# 10 is a positive number

# %%
b = -10
if b > 0:
    print(a, 'is a positive number')
    
print('End')
# Out:
# End

# %% [markdown]
# ****If the given condition is not met, then the instructions inside the if statement will be skipped****

# %% [markdown]
# ### Nested if Statements

# %% [raw]
# if 1st_condition:
#      Code that executes when '1st_condition' is True
#
#     if 2nd_condition:
#           Code that runs when '2nd_condition' and
#          '2nd_condition' are both True
#
#        if 3rd_condition:
#             # This statement will run only if both 1st and 2nd condtions are True
#
#             and so on................

# %%
x = input('Enter a number: ')
x = int(x)               #converting the number from string to integer
if x > 0:
    print('The number', x, 'is positive')
    if x % 2 == 0:
        print('The Number', x, 'is also even')
        if x > 10:
            print('The number', x, 'is also greater than 10')
# Out:
# Enter a number: 3
# The number 3 is positive

# %% [markdown]
# ### $\text{One Line if Statements}$

# %% [raw]
# # Syntax
# if <condition>: <instruction>

# %%
a ,b = 15,10
if a > b: print('a is greater than b')
# Out:
# a is greater than b

# %% [markdown]
# ****If there are multiple statements/instructions inside the body of 'if' statement, then it can be written as****

# %% [raw]
# if <condition>: <instruction_1>; <instruction_2>; <instruction_3>;.................;<instruction_n>

# %%
if 'z' in 'imtiaz': print('i'); print('m'), print('t'); print('i'); print('a'); print('z')
# Out:
# i
# m
# t
# i
# a
# z

# %% [markdown]
# ## $\color{blue}{\text{2. if-else Statement}}$

# %% [markdown]
# ![If_else_flow_diagram_C.jpg](attachment:If_else_flow_diagram_C.jpg)

# %% [raw]
# if condition:
#     runs the code inside "if" body
#     when condition is TRUE
# else:
#     runs code in else body
#     when condition is FALSE

# %% [markdown]
# ****if the condition in true then " if " body is excuted****
# ****otherwise else body is executed****

# %%
a = int(input("Enter a number: "))

if a%2 == 0:
    print('The number', a, 'is an Even number')
else:
    print('The number', a, 'is an Odd number')
# Out:
# Enter a number: 3
# The number 3 is an Odd number

# %% [markdown]
# ****Explaination of the above example:****
#
# ****input() function first takes the input number from user*****
#
# ****The (a % 2 == 0) is the condition which means the "remainder of a divided by 2 is equal to 0" then****
#
# * ****if this condition is True then run the body of " if " and everything inside else body is ignored/skipped****
#
# * ****if the given condition is not met then run the body of else statement and ignore the " if " body****

# %%
x = int(input('Enter first number: '))
y = int(input('Enter second number: '))

if x > y:
    print('\nx is greater than y\n')
    print('(Running if block)\n')
else:
    print('\ny is greater than x\n')
    print('(Running else block)')
# Out:
# Enter first number: 2
# Enter second number: 3
#
# y is greater than x
#
# (Running else block)

# %%
fruits = ('apple', 'banana','mango', 'orange')

fruit = input("Enter a fruit name: ")

if fruit in fruits:
    print(fruit, "is the tuple of fruits")
else:
    print("\n",fruit, "is not in the list of fruits :p")
# Out:
# Enter a fruit name: apple
# apple is the tuple of fruits

# %% [markdown]
# ### $\text{One line if-else Statements}$

# %%
x , y = int(input('Enter x: ')), int(input('Enter y: '))
if x > y : print(x, 'is greater', y); print('x is ', x, ' and y is ', y); print('know it clear')
else: print(y ,'is greater than ', x); print('x is ', x,'and y is ', y); print('Is this clear')
# Out:
# Enter x: 4
# Enter y: 5
# 5 is greater than  4
# x is  4 and y is  5
# Is this clear

# %% [markdown]
# ## $\color{blue}{\text{3. if-elif-else Statements}}$

# %% [markdown]
# #### In if-elif-else statements;
# * *1) multiple conditions are checked*
# * *2) if the condition for " if " is FALSE, then the condition in " elif " is executed and so on.*
# * *3) if all the conditions are found to be FALSE then and only then the body of " else " is executed.*

# %% [raw]
# if <condition>:
#     code in if body is executed
#
# elif <condition>
#     if condition for "if" is found FALSE then condition in elif body is teseted
#
# else:
#     code in else body is execeuted if all the above conditions are found to be FALSE

# %% [markdown]
# ![if-elseif-ladder.jpg](attachment:if-elseif-ladder.jpg)

# %%
a = int(input('Enter a value of a: '))
b = int(input('Enter a value of b: '))

if a > b: 
    print('a is greater than b')
elif a < b:
    print('a is smaller than b')
else:
    print('a and b are equal')
# Out:
# Enter a value of a: 3
# Enter a value of b: 4
# a is smaller than b

# %%
a = int(input('Enter a value of a: '))

if a > 0:
    print('The given number is Positive')
    if a%2 == 0:
        print(a, 'is an Even number')
    else:
        print(a, 'is an Odd number')
elif a < 0:
    print('The given number is Negative')
    if a%2 == 0:
        print(a, 'is a negative even')
else:
    print('The given number is Zero')
# Out:
# Enter a value of a: 4
# The given number is Positive
# 4 is an Even number

# %% [markdown]
# ### $\text{Nested if-else statements}$
# It will be clear by the following example

# %% [markdown]
# ****Writing a program to accept a number from 1 to 7 and display the name of the day like 1 for Sunday , 2 for Monday and so on****

# %%
number = int(input('Enter a number between 1 and 7: '))
if number == 1:
    print('1 for Sunday')
elif number == 2:
    print('2 for Monday')
elif number == 3:
    print('3 for Tuesday')
elif number == 4:
    print('4 for Wednesday')
elif number == 5:
    print('5 for Thursday')
elif number == 6:
    print('6 for Friday')
elif number == 7:
    print('7 for Saturday')
else:
    print('Enter a number between 1 and 7: ')
# Out:
# Enter a number between 1 and 7: 6
# 6 for Friday

# %% [markdown]
# ### $\text{One line if-elif-else Statements}$

# %%
x , y , z = int(input('Enter x: ')), int(input('Enter y: ')), int(input('Enter z: '))   #asking user to choose values

if x > y and x > z : print('\nx is greatest of them all'); print('\n x , the authority'); print('\n Is this clear')
elif y > x and y > z: print('\ny is greatest of them all'); print('\n x , the authority'); print('\nIs this clear')
elif z > x and z > y: print('\nz is greatest of them all'); print('\n x , the authority'); print('\nIs this clear')
else: print('\Enter correct numbers')
# Out:
# Enter x: 4
# Enter y: 5
# Enter z: 6
#
# z is greatest of them all
#
#  x , the authority
#
# Is this clear

# %% [markdown]
# ## $\text{Conditional Expressions OR Python's Ternary Operator}$

# %% [markdown]
# ![ternary%20operator.png](attachment:ternary%20operator.png)

# %% [markdown]
# ****Ternary Operators are the Operators that evaluate something based on condition being true or false****
#
# ****The condition is first executed, and if turns out to be "True" than first statement is executed otherwise second statement is executed****

# %% [markdown]
# #### $Syntax$

# %% [raw]
# <Statement No 1> if <Condition> else <Statement No 2>

# %% [markdown]
# ****1) Condition is evaluated first****
#
# ****2) If "condition" holds "True" then Statement No 1 is executed****
#
# ****3) If "condition" holds "False" then Statement No 2 is executed****

# %%
a = int(input('Enter a number: '))
b = int(input('Enter a 2nd number: '))

m = (a + 5) if a > b else (b + 5)
print(m)
# Out:
# Enter a number: 3
# Enter a 2nd number: 4
# 9

# %%
x = int(input('Enter the value of x: '))
y = int(input('Enter the value of y: '))

z = (x-2)  if x >= y else (y+2)
print(z)
# Out:
# Enter the value of x: 3
# Enter the value of y: 4
# 6

# %% [markdown]
# ****Conditional statements can also be combined into multiple conditions like alternative if-elif-else statements like****

# %%
x = int(input('Enter a number: '))
series = ('Peshawar' if x <= 10 else
        'Islamabad' if (x > 10 and x <= 20) else
         'Karachi' if (x > 20 and x <= 30) else
         'Lahore' if (x > 30 and x <= 40) else
         'DI Khan' if (x >= 40) else 'Enter a correct number'
         )
print(series)
# Out:
# Enter a number: 30
# Karachi
